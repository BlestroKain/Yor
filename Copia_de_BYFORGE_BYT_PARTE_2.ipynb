# %% [markdown]
# <a href="https://colab.research.google.com/github/BlestroKain/Yor/blob/main/Copia_de_BYFORGE_BYT_PARTE_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *Asignacion de estudiantes en base a la malla curricular*

# %%
import pandas as pd
import random
import os
import datetime
import logging
import platform

def log_event(message):
    # Reemplazamos la funcionalidad de log_event con print para pruebas
    print(message)

# Encabezado del log con información del sistema y usuario
#user_name = os.getlogin()
system_info = platform.uname()
#print(f"Usuario: {user_name}")
print(f"Sistema: {system_info.system}")
print(f"Nodo: {system_info.node}")
print(f"Release: {system_info.release}")
print(f"Versión: {system_info.version}")
print(f"Máquina: {system_info.machine}")
print(f"Procesador: {system_info.processor}")
print(f"_____________________________________________________________________________________")
# Función para leer nombres y apellidos de los archivos proporcionados
def read_names(file):
    return pd.read_csv(file, header=None, skiprows=1, encoding='utf-8').squeeze().tolist()

# Generación de datos únicos para los estudiantes
def generate_students(num_students, first_names, last_names):
    students = []
    unique_names = set()
    while len(students) < num_students:
        full_name = f"{random.choice(first_names)} {random.choice(last_names)}"
        if full_name not in unique_names:
            unique_names.add(full_name)
            students.append({'Nombre Completo': full_name})
    return students

# Distribución de estudiantes entre los semestres
def distribute_students(students):
    distribution = [0.14, 0.13, 0.12, 0.11, 0.10, 0.10, 0.09, 0.08, 0.07, 0.06]
    semester_counts = [int(len(students) * p) for p in distribution]
    semesters = []
    for i, count in enumerate(semester_counts):
        semesters.extend([i + 1] * count)
    random.shuffle(semesters)
    for student, semester in zip(students, semesters):
        student['Semestre'] = semester
    return students

# Función para obtener las iniciales del curso
def obtener_iniciales(nombre):
    palabras_comunes = {"DE", "LA", "DEL", "Y", "EL", "LOS", "LAS"}
    palabras = nombre.split()
    iniciales = [palabra[:3] for palabra in palabras if palabra.upper() not in palabras_comunes]
    return "".join(iniciales).upper()[:3]

# Función para calcular HTD y HTI basadas en los créditos
def calcular_horas(creditos):
    if creditos == 4:
        return 96, 120
    if creditos == 3:
        return 64, 80
    if creditos == 2:
        return 32, 64
    if creditos == 1:
        return 16, 32
    return 0, 0

# Generar el código único para cada materia
def generar_codigo(nombre, nivel, creditos, consecutivo):
    iniciales = obtener_iniciales(nombre)
    return f"{iniciales}{nivel}{creditos}{consecutivo}"

# Crear archivos de cursos
def create_course_files(students, courses, folder_path):
    start_time = datetime.datetime.now()
    log_event("Inicio de la creación de archivos de cursos")

    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
    grouped = {course: [] for course in courses}

    for student in students:
        for course, info in courses.items():
            if student['Semestre'] in info['Semestres']:
                grouped[course].append(student)

    for course, data in grouped.items():
        course_path = os.path.join(folder_path, f"Semestre {courses[course]['Semestres'][0]}", course)
        if not os.path.exists(course_path):
            os.makedirs(course_path)
        num_groups = len(data) // courses[course]['Cupo'] + (1 if len(data) % courses[course]['Cupo'] else 0)
        for i in range(num_groups):
            group_data = data[i * courses[course]['Cupo']:(i + 1) * courses[course]['Cupo']]
            if group_data:
                df = pd.DataFrame(group_data)[['Nombre Completo']]
                code = course
                course_name = courses[course]['Nombre'].replace(" ", "").capitalize()
                student_count = len(group_data)
                group_code = i + 1
                filename = f"{code}-{course_name}-{student_count}-{group_code}"
                filepath_csv = os.path.join(course_path, f"{filename}.csv")
                filepath_excel = os.path.join(course_path, f"{filename}.xlsx")
              # Crear archivo CSV
                csv_start_time = datetime.datetime.now()
                df.to_csv(filepath_csv, index=False, encoding='utf-8-sig')
                csv_end_time = datetime.datetime.now()
                csv_time_taken = csv_end_time - csv_start_time
                log_event(f'Creado archivo CSV: {filepath_csv}. Tiempo: {csv_time_taken}')

                # Crear archivo Excel
                excel_start_time = datetime.datetime.now()
                df.to_excel(filepath_excel, index=False)
                excel_end_time = datetime.datetime.now()
                excel_time_taken = excel_end_time - excel_start_time
                log_event(f'Creado archivo Excel: {filepath_excel}. Tiempo: {excel_time_taken}')

    end_time = datetime.datetime.now()
    total_time_taken = end_time - start_time
    log_event(f"Fin de la creación de archivos de cursos. Tiempo total: {total_time_taken}")


# Lista de materias con información
materias = [
    {"nivel": 1, "nombre": "INGLÉS I", "creditos": 1},
    {"nivel": 1, "nombre": "INTRODUCCIÓN A LA INGENIERÍA INDUSTRIAL", "creditos": 1},
    {"nivel": 1, "nombre": "ÁLGEBRA Y TRIGONOMETRÍA", "creditos": 3},
    {"nivel": 1, "nombre": "GEOMETRÍA VECTORIAL Y ANALÍTICA", "creditos": 3},
    {"nivel": 1, "nombre": "CÁLCULO DIFERENCIAL", "creditos": 3},
    {"nivel": 1, "nombre": "LECTOESCRITURA", "creditos": 3},
    {"nivel": 1, "nombre": "VIVAMOS LA UNIVERSIDAD", "creditos": 1},
    {"nivel": 2, "nombre": "INGLÉS II", "creditos": 1},
    {"nivel": 2, "nombre": "GESTIÓN DE LAS ORGANIZACIONES", "creditos": 3},
    {"nivel": 2, "nombre": "HABILIDADES GERENCIALES", "creditos": 3},
    {"nivel": 2, "nombre": "ÁLGEBRA LINEAL", "creditos": 3},
    {"nivel": 2, "nombre": "CÁLCULO INTEGRAL", "creditos": 3},
    {"nivel": 2, "nombre": "DESCUBRIENDO LA FÍSICA", "creditos": 3},
    {"nivel": 3, "nombre": "INGLÉS III", "creditos": 1},
    {"nivel": 3, "nombre": "GESTIÓN CONTABLE", "creditos": 3},
    {"nivel": 3, "nombre": "TEORÍA GENERAL DE SISTEMAS", "creditos": 3},
    {"nivel": 3, "nombre": "PROBABILIDAD E INFERENCIA ESTADÍSTICA", "creditos": 3},
    {"nivel": 3, "nombre": "ALGORITMIA Y PROGRAMACIÓN", "creditos": 3},
    {"nivel": 3, "nombre": "FÍSICA MECÁNICA", "creditos": 3},
    {"nivel": 4, "nombre": "INGLÉS IV", "creditos": 1},
    {"nivel": 4, "nombre": "GESTIÓN DE MÉTODOS Y TIEMPOS", "creditos": 4},
    {"nivel": 4, "nombre": "INGENIERÍA ECONÓMICA", "creditos": 3},
    {"nivel": 4, "nombre": "DISEÑO DE EXPERIMENTOS Y ANÁLISIS DE REGRESIÓN", "creditos": 3},
    {"nivel": 4, "nombre": "OPTIMIZACIÓN", "creditos": 3},
    {"nivel": 5, "nombre": "INGLÉS V", "creditos": 1},
    {"nivel": 5, "nombre": "DINÁMICA DE SISTEMAS", "creditos": 3},
    {"nivel": 5, "nombre": "GESTIÓN POR PROCESOS", "creditos": 3},
    {"nivel": 5, "nombre": "GESTIÓN FINANCIERA", "creditos": 3},
    {"nivel": 5, "nombre": "MUESTREO Y SERIES DE TIEMPO", "creditos": 3},
    {"nivel": 5, "nombre": "PROCESOS ESTOCÁSTICOS Y ANÁLISIS DE DECISIÓN", "creditos": 3},
    {"nivel": 6, "nombre": "INGLÉS VI", "creditos": 1},
    {"nivel": 6, "nombre": "GESTIÓN TECNOLÓGICA", "creditos": 3},
    {"nivel": 6, "nombre": "NORMALIZACIÓN Y CONTROL DE CALIDAD", "creditos": 3},
    {"nivel": 6, "nombre": "SIMULACIÓN", "creditos": 3},
    {"nivel": 6, "nombre": "SEGURIDAD Y SALUD EN EL TRABAJO", "creditos": 3},
    {"nivel": 7, "nombre": "GESTIÓN AMBIENTAL", "creditos": 3},
    {"nivel": 7, "nombre": "FORMULACIÓN Y EVALUACIÓN DE PROYECTOS", "creditos": 3},
    {"nivel": 7, "nombre": "GESTIÓN LOGÍSTICA Y DE LA CADENA DE SUMINISTRO", "creditos": 3},
    {"nivel": 7, "nombre": "MODELACIÓN DE SISTEMAS Y SIMULACIÓN DE PROCESOS", "creditos": 3},
    {"nivel": 8, "nombre": "GESTIÓN DEL TALENTO HUMANO", "creditos": 3},
    {"nivel": 8, "nombre": "GESTIÓN DE SERVICIOS", "creditos": 3},
    {"nivel": 8, "nombre": "PLANIFICACIÓN Y CONTROL DE LA PRODUCCIÓN", "creditos": 3},
    {"nivel": 8, "nombre": "PLANEACIÓN ESTRATÉGICA", "creditos": 3},
    {"nivel": 9, "nombre": "INVESTIGACIÓN DE MERCADOS Y ANÁLISIS DE LA COMPETENCIA", "creditos": 3},
    {"nivel": 9, "nombre": "PRÁCTICAS PROFESIONALES", "creditos": 3},
]

# Cursos y su configuración
courses = {}
consecutivo = 1
for materia in materias:
    codigo = generar_codigo(materia['nombre'], materia['nivel'], materia['creditos'], consecutivo)
    courses[codigo] = {
        'Semestres': [materia['nivel']],
        'Cupo': 30 if materia['nivel'] < 4 else 25 if materia['nivel'] < 7 else 20,
        'HTD': calcular_horas(materia['creditos'])[0],
        'HTI': calcular_horas(materia['creditos'])[1],
        'Nombre': materia['nombre']
    }
    consecutivo += 1

# Archivos de nombres y apellidos
first_names = read_names('nombres.csv')
last_names = read_names('apellidos.csv')

# Generar y distribuir estudiantes
students = generate_students(1000, first_names, last_names)
students = distribute_students(students)

# Crear archivos de cursos
create_course_files(students, courses, 'Ruta Trabajo Final')

# Finalizar el log de eventos con un resumen
total_files = sum([len(files) for r, d, files in os.walk('Ruta Trabajo Final')])
print(f"Total de archivos creados: {total_files}")
print(f"Total de acciones realizadas: {total_files * 2}")  # Cada archivo implica crear CSV y Excel, así que se multiplica por 2
# Out:
# Sistema: Linux
# Nodo: 8ca301c7bfc1
# Release: 6.1.85+
# Versión: #1 SMP PREEMPT_DYNAMIC Sun Apr 28 14:29:16 UTC 2024
# Máquina: x86_64
# Procesador: x86_64
# _____________________________________________________________________________________
# Inicio de la creación de archivos de cursos
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-30-1.csv. Tiempo: 0:00:00.005543
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-30-1.xlsx. Tiempo: 0:00:00.284841
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-30-2.csv. Tiempo: 0:00:00.001772
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-30-2.xlsx. Tiempo: 0:00:00.008810
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-30-3.csv. Tiempo: 0:00:00.001258
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-30-3.xlsx. Tiempo: 0:00:00.008641
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-30-4.csv. Tiempo: 0:00:00.001157
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-30-4.xlsx. Tiempo: 0:00:00.008344
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-20-5.csv. Tiempo: 0:00:00.001154
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-20-5.xlsx. Tiempo: 0:00:00.007824
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-30-1.csv. Tiempo: 0:00:00.000622
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-30-1.xlsx. Tiempo: 0:00:00.008091
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-30-2.csv. Tiempo: 0:00:00.001147
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-30-2.xlsx. Tiempo: 0:00:00.008131
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-30-3.csv. Tiempo: 0:00:00.001196
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-30-3.xlsx. Tiempo: 0:00:00.009349
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-30-4.csv. Tiempo: 0:00:00.001091
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-30-4.xlsx. Tiempo: 0:00:00.007940
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-20-5.csv. Tiempo: 0:00:00.001109
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-20-5.xlsx. Tiempo: 0:00:00.008724
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-30-1.csv. Tiempo: 0:00:00.000607
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-30-1.xlsx. Tiempo: 0:00:00.007714
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-30-2.csv. Tiempo: 0:00:00.001113
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-30-2.xlsx. Tiempo: 0:00:00.008005
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-30-3.csv. Tiempo: 0:00:00.001099
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-30-3.xlsx. Tiempo: 0:00:00.007759
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-30-4.csv. Tiempo: 0:00:00.001078
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-30-4.xlsx. Tiempo: 0:00:00.007916
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-20-5.csv. Tiempo: 0:00:00.001099
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-20-5.xlsx. Tiempo: 0:00:00.007739
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-30-1.csv. Tiempo: 0:00:00.000619
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-30-1.xlsx. Tiempo: 0:00:00.008122
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-30-2.csv. Tiempo: 0:00:00.001084
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-30-2.xlsx. Tiempo: 0:00:00.012848
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-30-3.csv. Tiempo: 0:00:00.001313
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-30-3.xlsx. Tiempo: 0:00:00.008264
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-30-4.csv. Tiempo: 0:00:00.001160
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-30-4.xlsx. Tiempo: 0:00:00.008486
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-20-5.csv. Tiempo: 0:00:00.001171
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-20-5.xlsx. Tiempo: 0:00:00.011667
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-30-1.csv. Tiempo: 0:00:00.000741
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-30-1.xlsx. Tiempo: 0:00:00.008289
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-30-2.csv. Tiempo: 0:00:00.001210
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-30-2.xlsx. Tiempo: 0:00:00.008597
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-30-3.csv. Tiempo: 0:00:00.001226
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-30-3.xlsx. Tiempo: 0:00:00.008346
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-30-4.csv. Tiempo: 0:00:00.001288
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-30-4.xlsx. Tiempo: 0:00:00.008867
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-20-5.csv. Tiempo: 0:00:00.001372
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-20-5.xlsx. Tiempo: 0:00:00.008129
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-30-1.csv. Tiempo: 0:00:00.000663
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-30-1.xlsx. Tiempo: 0:00:00.008646
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-30-2.csv. Tiempo: 0:00:00.000934
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-30-2.xlsx. Tiempo: 0:00:00.015860
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-30-3.csv. Tiempo: 0:00:00.001159
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-30-3.xlsx. Tiempo: 0:00:00.013286
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-30-4.csv. Tiempo: 0:00:00.001060
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-30-4.xlsx. Tiempo: 0:00:00.014290
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-20-5.csv. Tiempo: 0:00:00.001741
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-20-5.xlsx. Tiempo: 0:00:00.013710
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-30-1.csv. Tiempo: 0:00:00.001086
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-30-1.xlsx. Tiempo: 0:00:00.012862
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-30-2.csv. Tiempo: 0:00:00.000930
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-30-2.xlsx. Tiempo: 0:00:00.013315
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-30-3.csv. Tiempo: 0:00:00.000988
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-30-3.xlsx. Tiempo: 0:00:00.012555
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-30-4.csv. Tiempo: 0:00:00.001921
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-30-4.xlsx. Tiempo: 0:00:00.015234
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-20-5.csv. Tiempo: 0:00:00.001108
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-20-5.xlsx. Tiempo: 0:00:00.012425
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-30-1.csv. Tiempo: 0:00:00.001037
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-30-1.xlsx. Tiempo: 0:00:00.012791
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-30-2.csv. Tiempo: 0:00:00.001796
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-30-2.xlsx. Tiempo: 0:00:00.013446
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-30-3.csv. Tiempo: 0:00:00.001579
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-30-3.xlsx. Tiempo: 0:00:00.011543
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-30-4.csv. Tiempo: 0:00:00.001067
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-30-4.xlsx. Tiempo: 0:00:00.014454
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-10-5.csv. Tiempo: 0:00:00.000968
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-10-5.xlsx. Tiempo: 0:00:00.016450
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-30-1.csv. Tiempo: 0:00:00.001036
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-30-1.xlsx. Tiempo: 0:00:00.013008
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-30-2.csv. Tiempo: 0:00:00.001629
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-30-2.xlsx. Tiempo: 0:00:00.012335
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-30-3.csv. Tiempo: 0:00:00.001523
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-30-3.xlsx. Tiempo: 0:00:00.011606
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-30-4.csv. Tiempo: 0:00:00.000908
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-30-4.xlsx. Tiempo: 0:00:00.011984
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-10-5.csv. Tiempo: 0:00:00.000877
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-10-5.xlsx. Tiempo: 0:00:00.011281
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-30-1.csv. Tiempo: 0:00:00.001837
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-30-1.xlsx. Tiempo: 0:00:00.014974
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-30-2.csv. Tiempo: 0:00:00.001337
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-30-2.xlsx. Tiempo: 0:00:00.012417
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-30-3.csv. Tiempo: 0:00:00.001585
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-30-3.xlsx. Tiempo: 0:00:00.012390
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-30-4.csv. Tiempo: 0:00:00.001994
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-30-4.xlsx. Tiempo: 0:00:00.012440
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-10-5.csv. Tiempo: 0:00:00.000862
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-10-5.xlsx. Tiempo: 0:00:00.010650
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-30-1.csv. Tiempo: 0:00:00.000902
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-30-1.xlsx. Tiempo: 0:00:00.011428
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-30-2.csv. Tiempo: 0:00:00.001475
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-30-2.xlsx. Tiempo: 0:00:00.011759
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-30-3.csv. Tiempo: 0:00:00.000947
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-30-3.xlsx. Tiempo: 0:00:00.010273
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-30-4.csv. Tiempo: 0:00:00.001591
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-30-4.xlsx. Tiempo: 0:00:00.012300
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-10-5.csv. Tiempo: 0:00:00.000877
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-10-5.xlsx. Tiempo: 0:00:00.011671
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-30-1.csv. Tiempo: 0:00:00.000898
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-30-1.xlsx. Tiempo: 0:00:00.011821
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-30-2.csv. Tiempo: 0:00:00.000909
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-30-2.xlsx. Tiempo: 0:00:00.011794
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-30-3.csv. Tiempo: 0:00:00.000898
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-30-3.xlsx. Tiempo: 0:00:00.013344
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-30-4.csv. Tiempo: 0:00:00.000935
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-30-4.xlsx. Tiempo: 0:00:00.015214
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-10-5.csv. Tiempo: 0:00:00.000942
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-10-5.xlsx. Tiempo: 0:00:00.011478
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-30-1.csv. Tiempo: 0:00:00.001035
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-30-1.xlsx. Tiempo: 0:00:00.012412
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-30-2.csv. Tiempo: 0:00:00.001042
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-30-2.xlsx. Tiempo: 0:00:00.011954
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-30-3.csv. Tiempo: 0:00:00.000951
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-30-3.xlsx. Tiempo: 0:00:00.011409
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-30-4.csv. Tiempo: 0:00:00.000906
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-30-4.xlsx. Tiempo: 0:00:00.012517
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-10-5.csv. Tiempo: 0:00:00.000942
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-10-5.xlsx. Tiempo: 0:00:00.010774
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/ING3114/ING3114-Inglésiii-30-1.csv. Tiempo: 0:00:00.000970
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/ING3114/ING3114-Inglésiii-30-1.xlsx. Tiempo: 0:00:00.012091
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/ING3114/ING3114-Inglésiii-30-2.csv. Tiempo: 0:00:00.000945
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/ING3114/ING3114-Inglésiii-30-2.xlsx. Tiempo: 0:00:00.011631
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/ING3114/ING3114-Inglésiii-30-3.csv. Tiempo: 0:00:00.000974
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/ING3114/ING3114-Inglésiii-30-3.xlsx. Tiempo: 0:00:00.011847
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/ING3114/ING3114-Inglésiii-30-4.csv. Tiempo: 0:00:00.000938
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/ING3114/ING3114-Inglésiii-30-4.xlsx. Tiempo: 0:00:00.011459
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/GES3315/GES3315-Gestióncontable-30-1.csv. Tiempo: 0:00:00.000955
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/GES3315/GES3315-Gestióncontable-30-1.xlsx. Tiempo: 0:00:00.011943
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/GES3315/GES3315-Gestióncontable-30-2.csv. Tiempo: 0:00:00.000981
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/GES3315/GES3315-Gestióncontable-30-2.xlsx. Tiempo: 0:00:00.011531
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/GES3315/GES3315-Gestióncontable-30-3.csv. Tiempo: 0:00:00.000897
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/GES3315/GES3315-Gestióncontable-30-3.xlsx. Tiempo: 0:00:00.012696
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/GES3315/GES3315-Gestióncontable-30-4.csv. Tiempo: 0:00:00.000964
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/GES3315/GES3315-Gestióncontable-30-4.xlsx. Tiempo: 0:00:00.011637
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/TEO3316/TEO3316-Teoríageneraldesistemas-30-1.csv. Tiempo: 0:00:00.000948
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/TEO3316/TEO3316-Teoríageneraldesistemas-30-1.xlsx. Tiempo: 0:00:00.011878
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/TEO3316/TEO3316-Teoríageneraldesistemas-30-2.csv. Tiempo: 0:00:00.000961
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/TEO3316/TEO3316-Teoríageneraldesistemas-30-2.xlsx. Tiempo: 0:00:00.011596
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/TEO3316/TEO3316-Teoríageneraldesistemas-30-3.csv. Tiempo: 0:00:00.000929
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/TEO3316/TEO3316-Teoríageneraldesistemas-30-3.xlsx. Tiempo: 0:00:00.012077
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/TEO3316/TEO3316-Teoríageneraldesistemas-30-4.csv. Tiempo: 0:00:00.000926
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/TEO3316/TEO3316-Teoríageneraldesistemas-30-4.xlsx. Tiempo: 0:00:00.015510
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/PRO3317/PRO3317-Probabilidadeinferenciaestadística-30-1.csv. Tiempo: 0:00:00.000947
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/PRO3317/PRO3317-Probabilidadeinferenciaestadística-30-1.xlsx. Tiempo: 0:00:00.011675
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/PRO3317/PRO3317-Probabilidadeinferenciaestadística-30-2.csv. Tiempo: 0:00:00.000892
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/PRO3317/PRO3317-Probabilidadeinferenciaestadística-30-2.xlsx. Tiempo: 0:00:00.011543
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/PRO3317/PRO3317-Probabilidadeinferenciaestadística-30-3.csv. Tiempo: 0:00:00.000999
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/PRO3317/PRO3317-Probabilidadeinferenciaestadística-30-3.xlsx. Tiempo: 0:00:00.012051
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/PRO3317/PRO3317-Probabilidadeinferenciaestadística-30-4.csv. Tiempo: 0:00:00.000946
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/PRO3317/PRO3317-Probabilidadeinferenciaestadística-30-4.xlsx. Tiempo: 0:00:00.011493
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/ALG3318/ALG3318-Algoritmiayprogramación-30-1.csv. Tiempo: 0:00:00.000895
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/ALG3318/ALG3318-Algoritmiayprogramación-30-1.xlsx. Tiempo: 0:00:00.012453
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/ALG3318/ALG3318-Algoritmiayprogramación-30-2.csv. Tiempo: 0:00:00.001246
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/ALG3318/ALG3318-Algoritmiayprogramación-30-2.xlsx. Tiempo: 0:00:00.012718
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/ALG3318/ALG3318-Algoritmiayprogramación-30-3.csv. Tiempo: 0:00:00.001012
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/ALG3318/ALG3318-Algoritmiayprogramación-30-3.xlsx. Tiempo: 0:00:00.012016
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/ALG3318/ALG3318-Algoritmiayprogramación-30-4.csv. Tiempo: 0:00:00.000933
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/ALG3318/ALG3318-Algoritmiayprogramación-30-4.xlsx. Tiempo: 0:00:00.016984
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/FÍS3319/FÍS3319-Físicamecánica-30-1.csv. Tiempo: 0:00:00.001039
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/FÍS3319/FÍS3319-Físicamecánica-30-1.xlsx. Tiempo: 0:00:00.012211
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/FÍS3319/FÍS3319-Físicamecánica-30-2.csv. Tiempo: 0:00:00.000998
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/FÍS3319/FÍS3319-Físicamecánica-30-2.xlsx. Tiempo: 0:00:00.011869
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/FÍS3319/FÍS3319-Físicamecánica-30-3.csv. Tiempo: 0:00:00.001040
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/FÍS3319/FÍS3319-Físicamecánica-30-3.xlsx. Tiempo: 0:00:00.015976
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/FÍS3319/FÍS3319-Físicamecánica-30-4.csv. Tiempo: 0:00:00.001223
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/FÍS3319/FÍS3319-Físicamecánica-30-4.xlsx. Tiempo: 0:00:00.013688
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-25-1.csv. Tiempo: 0:00:00.001048
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-25-1.xlsx. Tiempo: 0:00:00.012068
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-25-2.csv. Tiempo: 0:00:00.000992
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-25-2.xlsx. Tiempo: 0:00:00.011702
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-25-3.csv. Tiempo: 0:00:00.001020
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-25-3.xlsx. Tiempo: 0:00:00.011940
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-25-4.csv. Tiempo: 0:00:00.000973
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-25-4.xlsx. Tiempo: 0:00:00.011662
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-10-5.csv. Tiempo: 0:00:00.000936
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-10-5.xlsx. Tiempo: 0:00:00.016492
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-25-1.csv. Tiempo: 0:00:00.001044
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-25-1.xlsx. Tiempo: 0:00:00.020995
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-25-2.csv. Tiempo: 0:00:00.001093
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-25-2.xlsx. Tiempo: 0:00:00.012034
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-25-3.csv. Tiempo: 0:00:00.001099
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-25-3.xlsx. Tiempo: 0:00:00.014607
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-25-4.csv. Tiempo: 0:00:00.001069
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-25-4.xlsx. Tiempo: 0:00:00.013209
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-10-5.csv. Tiempo: 0:00:00.000991
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-10-5.xlsx. Tiempo: 0:00:00.011528
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-25-1.csv. Tiempo: 0:00:00.001021
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-25-1.xlsx. Tiempo: 0:00:00.011541
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-25-2.csv. Tiempo: 0:00:00.000964
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-25-2.xlsx. Tiempo: 0:00:00.011738
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-25-3.csv. Tiempo: 0:00:00.000910
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-25-3.xlsx. Tiempo: 0:00:00.015384
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-25-4.csv. Tiempo: 0:00:00.000944
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-25-4.xlsx. Tiempo: 0:00:00.013815
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-10-5.csv. Tiempo: 0:00:00.000898
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-10-5.xlsx. Tiempo: 0:00:00.014885
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-25-1.csv. Tiempo: 0:00:00.000998
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-25-1.xlsx. Tiempo: 0:00:00.015658
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-25-2.csv. Tiempo: 0:00:00.001024
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-25-2.xlsx. Tiempo: 0:00:00.014089
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-25-3.csv. Tiempo: 0:00:00.001012
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-25-3.xlsx. Tiempo: 0:00:00.011918
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-25-4.csv. Tiempo: 0:00:00.000930
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-25-4.xlsx. Tiempo: 0:00:00.011836
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-10-5.csv. Tiempo: 0:00:00.000962
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-10-5.xlsx. Tiempo: 0:00:00.011162
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-25-1.csv. Tiempo: 0:00:00.000939
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-25-1.xlsx. Tiempo: 0:00:00.013301
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-25-2.csv. Tiempo: 0:00:00.000935
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-25-2.xlsx. Tiempo: 0:00:00.011933
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-25-3.csv. Tiempo: 0:00:00.000962
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-25-3.xlsx. Tiempo: 0:00:00.013511
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-25-4.csv. Tiempo: 0:00:00.001075
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-25-4.xlsx. Tiempo: 0:00:00.012012
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-10-5.csv. Tiempo: 0:00:00.000934
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-10-5.xlsx. Tiempo: 0:00:00.010793
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/ING5125/ING5125-Inglésv-25-1.csv. Tiempo: 0:00:00.000919
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/ING5125/ING5125-Inglésv-25-1.xlsx. Tiempo: 0:00:00.011856
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/ING5125/ING5125-Inglésv-25-2.csv. Tiempo: 0:00:00.000951
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/ING5125/ING5125-Inglésv-25-2.xlsx. Tiempo: 0:00:00.012383
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/ING5125/ING5125-Inglésv-25-3.csv. Tiempo: 0:00:00.000937
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/ING5125/ING5125-Inglésv-25-3.xlsx. Tiempo: 0:00:00.011603
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/ING5125/ING5125-Inglésv-25-4.csv. Tiempo: 0:00:00.000964
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/ING5125/ING5125-Inglésv-25-4.xlsx. Tiempo: 0:00:00.011511
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/DIN5326/DIN5326-Dinámicadesistemas-25-1.csv. Tiempo: 0:00:00.000954
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/DIN5326/DIN5326-Dinámicadesistemas-25-1.xlsx. Tiempo: 0:00:00.012811
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/DIN5326/DIN5326-Dinámicadesistemas-25-2.csv. Tiempo: 0:00:00.000963
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/DIN5326/DIN5326-Dinámicadesistemas-25-2.xlsx. Tiempo: 0:00:00.011402
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/DIN5326/DIN5326-Dinámicadesistemas-25-3.csv. Tiempo: 0:00:00.000929
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/DIN5326/DIN5326-Dinámicadesistemas-25-3.xlsx. Tiempo: 0:00:00.011524
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/DIN5326/DIN5326-Dinámicadesistemas-25-4.csv. Tiempo: 0:00:00.000890
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/DIN5326/DIN5326-Dinámicadesistemas-25-4.xlsx. Tiempo: 0:00:00.011253
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/GES5327/GES5327-Gestiónporprocesos-25-1.csv. Tiempo: 0:00:00.000978
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/GES5327/GES5327-Gestiónporprocesos-25-1.xlsx. Tiempo: 0:00:00.014206
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/GES5327/GES5327-Gestiónporprocesos-25-2.csv. Tiempo: 0:00:00.001144
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/GES5327/GES5327-Gestiónporprocesos-25-2.xlsx. Tiempo: 0:00:00.011848
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/GES5327/GES5327-Gestiónporprocesos-25-3.csv. Tiempo: 0:00:00.000959
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/GES5327/GES5327-Gestiónporprocesos-25-3.xlsx. Tiempo: 0:00:00.011536
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/GES5327/GES5327-Gestiónporprocesos-25-4.csv. Tiempo: 0:00:00.000946
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/GES5327/GES5327-Gestiónporprocesos-25-4.xlsx. Tiempo: 0:00:00.011196
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/GES5328/GES5328-Gestiónfinanciera-25-1.csv. Tiempo: 0:00:00.000907
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/GES5328/GES5328-Gestiónfinanciera-25-1.xlsx. Tiempo: 0:00:00.011562
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/GES5328/GES5328-Gestiónfinanciera-25-2.csv. Tiempo: 0:00:00.000951
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/GES5328/GES5328-Gestiónfinanciera-25-2.xlsx. Tiempo: 0:00:00.011907
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/GES5328/GES5328-Gestiónfinanciera-25-3.csv. Tiempo: 0:00:00.001000
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/GES5328/GES5328-Gestiónfinanciera-25-3.xlsx. Tiempo: 0:00:00.013184
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/GES5328/GES5328-Gestiónfinanciera-25-4.csv. Tiempo: 0:00:00.001060
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/GES5328/GES5328-Gestiónfinanciera-25-4.xlsx. Tiempo: 0:00:00.011734
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/MUE5329/MUE5329-Muestreoyseriesdetiempo-25-1.csv. Tiempo: 0:00:00.001019
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/MUE5329/MUE5329-Muestreoyseriesdetiempo-25-1.xlsx. Tiempo: 0:00:00.011927
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/MUE5329/MUE5329-Muestreoyseriesdetiempo-25-2.csv. Tiempo: 0:00:00.000926
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/MUE5329/MUE5329-Muestreoyseriesdetiempo-25-2.xlsx. Tiempo: 0:00:00.014765
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/MUE5329/MUE5329-Muestreoyseriesdetiempo-25-3.csv. Tiempo: 0:00:00.001134
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/MUE5329/MUE5329-Muestreoyseriesdetiempo-25-3.xlsx. Tiempo: 0:00:00.014719
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/MUE5329/MUE5329-Muestreoyseriesdetiempo-25-4.csv. Tiempo: 0:00:00.001087
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/MUE5329/MUE5329-Muestreoyseriesdetiempo-25-4.xlsx. Tiempo: 0:00:00.012778
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/PRO5330/PRO5330-Procesosestocásticosyanálisisdedecisión-25-1.csv. Tiempo: 0:00:00.001043
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/PRO5330/PRO5330-Procesosestocásticosyanálisisdedecisión-25-1.xlsx. Tiempo: 0:00:00.013209
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/PRO5330/PRO5330-Procesosestocásticosyanálisisdedecisión-25-2.csv. Tiempo: 0:00:00.001042
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/PRO5330/PRO5330-Procesosestocásticosyanálisisdedecisión-25-2.xlsx. Tiempo: 0:00:00.011267
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/PRO5330/PRO5330-Procesosestocásticosyanálisisdedecisión-25-3.csv. Tiempo: 0:00:00.000968
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/PRO5330/PRO5330-Procesosestocásticosyanálisisdedecisión-25-3.xlsx. Tiempo: 0:00:00.012459
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/PRO5330/PRO5330-Procesosestocásticosyanálisisdedecisión-25-4.csv. Tiempo: 0:00:00.001663
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/PRO5330/PRO5330-Procesosestocásticosyanálisisdedecisión-25-4.xlsx. Tiempo: 0:00:00.011944
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/ING6131/ING6131-Inglésvi-25-1.csv. Tiempo: 0:00:00.001067
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/ING6131/ING6131-Inglésvi-25-1.xlsx. Tiempo: 0:00:00.014820
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/ING6131/ING6131-Inglésvi-25-2.csv. Tiempo: 0:00:00.001176
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/ING6131/ING6131-Inglésvi-25-2.xlsx. Tiempo: 0:00:00.012531
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/ING6131/ING6131-Inglésvi-25-3.csv. Tiempo: 0:00:00.001078
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/ING6131/ING6131-Inglésvi-25-3.xlsx. Tiempo: 0:00:00.011898
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/ING6131/ING6131-Inglésvi-25-4.csv. Tiempo: 0:00:00.000993
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/ING6131/ING6131-Inglésvi-25-4.xlsx. Tiempo: 0:00:00.011637
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/GES6332/GES6332-Gestióntecnológica-25-1.csv. Tiempo: 0:00:00.001042
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/GES6332/GES6332-Gestióntecnológica-25-1.xlsx. Tiempo: 0:00:00.011884
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/GES6332/GES6332-Gestióntecnológica-25-2.csv. Tiempo: 0:00:00.001572
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/GES6332/GES6332-Gestióntecnológica-25-2.xlsx. Tiempo: 0:00:00.012163
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/GES6332/GES6332-Gestióntecnológica-25-3.csv. Tiempo: 0:00:00.001114
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/GES6332/GES6332-Gestióntecnológica-25-3.xlsx. Tiempo: 0:00:00.011212
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/GES6332/GES6332-Gestióntecnológica-25-4.csv. Tiempo: 0:00:00.001070
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/GES6332/GES6332-Gestióntecnológica-25-4.xlsx. Tiempo: 0:00:00.012222
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/NOR6333/NOR6333-Normalizaciónycontroldecalidad-25-1.csv. Tiempo: 0:00:00.000989
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/NOR6333/NOR6333-Normalizaciónycontroldecalidad-25-1.xlsx. Tiempo: 0:00:00.011872
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/NOR6333/NOR6333-Normalizaciónycontroldecalidad-25-2.csv. Tiempo: 0:00:00.000948
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/NOR6333/NOR6333-Normalizaciónycontroldecalidad-25-2.xlsx. Tiempo: 0:00:00.015962
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/NOR6333/NOR6333-Normalizaciónycontroldecalidad-25-3.csv. Tiempo: 0:00:00.001014
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/NOR6333/NOR6333-Normalizaciónycontroldecalidad-25-3.xlsx. Tiempo: 0:00:00.013210
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/NOR6333/NOR6333-Normalizaciónycontroldecalidad-25-4.csv. Tiempo: 0:00:00.000927
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/NOR6333/NOR6333-Normalizaciónycontroldecalidad-25-4.xlsx. Tiempo: 0:00:00.011339
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/SIM6334/SIM6334-Simulación-25-1.csv. Tiempo: 0:00:00.000897
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/SIM6334/SIM6334-Simulación-25-1.xlsx. Tiempo: 0:00:00.012218
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/SIM6334/SIM6334-Simulación-25-2.csv. Tiempo: 0:00:00.001072
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/SIM6334/SIM6334-Simulación-25-2.xlsx. Tiempo: 0:00:00.014823
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/SIM6334/SIM6334-Simulación-25-3.csv. Tiempo: 0:00:00.001076
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/SIM6334/SIM6334-Simulación-25-3.xlsx. Tiempo: 0:00:00.011891
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/SIM6334/SIM6334-Simulación-25-4.csv. Tiempo: 0:00:00.001906
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/SIM6334/SIM6334-Simulación-25-4.xlsx. Tiempo: 0:00:00.013160
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/SEG6335/SEG6335-Seguridadysaludeneltrabajo-25-1.csv. Tiempo: 0:00:00.001010
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/SEG6335/SEG6335-Seguridadysaludeneltrabajo-25-1.xlsx. Tiempo: 0:00:00.014818
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/SEG6335/SEG6335-Seguridadysaludeneltrabajo-25-2.csv. Tiempo: 0:00:00.001577
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/SEG6335/SEG6335-Seguridadysaludeneltrabajo-25-2.xlsx. Tiempo: 0:00:00.011958
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/SEG6335/SEG6335-Seguridadysaludeneltrabajo-25-3.csv. Tiempo: 0:00:00.000971
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/SEG6335/SEG6335-Seguridadysaludeneltrabajo-25-3.xlsx. Tiempo: 0:00:00.013937
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/SEG6335/SEG6335-Seguridadysaludeneltrabajo-25-4.csv. Tiempo: 0:00:00.001654
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/SEG6335/SEG6335-Seguridadysaludeneltrabajo-25-4.xlsx. Tiempo: 0:00:00.011888
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-20-1.csv. Tiempo: 0:00:00.000977
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-20-1.xlsx. Tiempo: 0:00:00.011457
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-20-2.csv. Tiempo: 0:00:00.000924
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-20-2.xlsx. Tiempo: 0:00:00.015893
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-20-3.csv. Tiempo: 0:00:00.002081
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-20-3.xlsx. Tiempo: 0:00:00.013849
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-20-4.csv. Tiempo: 0:00:00.001579
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-20-4.xlsx. Tiempo: 0:00:00.011517
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-10-5.csv. Tiempo: 0:00:00.000951
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-10-5.xlsx. Tiempo: 0:00:00.011562
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-20-1.csv. Tiempo: 0:00:00.000985
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-20-1.xlsx. Tiempo: 0:00:00.011521
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-20-2.csv. Tiempo: 0:00:00.001122
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-20-2.xlsx. Tiempo: 0:00:00.012692
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-20-3.csv. Tiempo: 0:00:00.001111
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-20-3.xlsx. Tiempo: 0:00:00.012634
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-20-4.csv. Tiempo: 0:00:00.001177
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-20-4.xlsx. Tiempo: 0:00:00.015414
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-10-5.csv. Tiempo: 0:00:00.004161
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-10-5.xlsx. Tiempo: 0:00:00.016731
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-20-1.csv. Tiempo: 0:00:00.001113
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-20-1.xlsx. Tiempo: 0:00:00.016621
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-20-2.csv. Tiempo: 0:00:00.001789
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-20-2.xlsx. Tiempo: 0:00:00.012275
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-20-3.csv. Tiempo: 0:00:00.001081
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-20-3.xlsx. Tiempo: 0:00:00.012242
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-20-4.csv. Tiempo: 0:00:00.001006
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-20-4.xlsx. Tiempo: 0:00:00.013886
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-10-5.csv. Tiempo: 0:00:00.001208
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-10-5.xlsx. Tiempo: 0:00:00.015431
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-20-1.csv. Tiempo: 0:00:00.001033
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-20-1.xlsx. Tiempo: 0:00:00.013084
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-20-2.csv. Tiempo: 0:00:00.001009
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-20-2.xlsx. Tiempo: 0:00:00.013085
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-20-3.csv. Tiempo: 0:00:00.000976
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-20-3.xlsx. Tiempo: 0:00:00.011436
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-20-4.csv. Tiempo: 0:00:00.000940
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-20-4.xlsx. Tiempo: 0:00:00.012485
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-10-5.csv. Tiempo: 0:00:00.000899
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-10-5.xlsx. Tiempo: 0:00:00.011025
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/GES8340/GES8340-Gestióndeltalentohumano-20-1.csv. Tiempo: 0:00:00.000939
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/GES8340/GES8340-Gestióndeltalentohumano-20-1.xlsx. Tiempo: 0:00:00.011346
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/GES8340/GES8340-Gestióndeltalentohumano-20-2.csv. Tiempo: 0:00:00.000920
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/GES8340/GES8340-Gestióndeltalentohumano-20-2.xlsx. Tiempo: 0:00:00.011471
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/GES8340/GES8340-Gestióndeltalentohumano-20-3.csv. Tiempo: 0:00:00.000906
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/GES8340/GES8340-Gestióndeltalentohumano-20-3.xlsx. Tiempo: 0:00:00.011582
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/GES8340/GES8340-Gestióndeltalentohumano-20-4.csv. Tiempo: 0:00:00.000906
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/GES8340/GES8340-Gestióndeltalentohumano-20-4.xlsx. Tiempo: 0:00:00.011460
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/GES8341/GES8341-Gestióndeservicios-20-1.csv. Tiempo: 0:00:00.000982
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/GES8341/GES8341-Gestióndeservicios-20-1.xlsx. Tiempo: 0:00:00.012003
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/GES8341/GES8341-Gestióndeservicios-20-2.csv. Tiempo: 0:00:00.001012
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/GES8341/GES8341-Gestióndeservicios-20-2.xlsx. Tiempo: 0:00:00.011801
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/GES8341/GES8341-Gestióndeservicios-20-3.csv. Tiempo: 0:00:00.000984
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/GES8341/GES8341-Gestióndeservicios-20-3.xlsx. Tiempo: 0:00:00.014142
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/GES8341/GES8341-Gestióndeservicios-20-4.csv. Tiempo: 0:00:00.001006
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/GES8341/GES8341-Gestióndeservicios-20-4.xlsx. Tiempo: 0:00:00.011898
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/PLA8342/PLA8342-Planificaciónycontroldelaproducción-20-1.csv. Tiempo: 0:00:00.001048
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/PLA8342/PLA8342-Planificaciónycontroldelaproducción-20-1.xlsx. Tiempo: 0:00:00.012481
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/PLA8342/PLA8342-Planificaciónycontroldelaproducción-20-2.csv. Tiempo: 0:00:00.001072
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/PLA8342/PLA8342-Planificaciónycontroldelaproducción-20-2.xlsx. Tiempo: 0:00:00.013259
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/PLA8342/PLA8342-Planificaciónycontroldelaproducción-20-3.csv. Tiempo: 0:00:00.001077
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/PLA8342/PLA8342-Planificaciónycontroldelaproducción-20-3.xlsx. Tiempo: 0:00:00.012829
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/PLA8342/PLA8342-Planificaciónycontroldelaproducción-20-4.csv. Tiempo: 0:00:00.001165
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/PLA8342/PLA8342-Planificaciónycontroldelaproducción-20-4.xlsx. Tiempo: 0:00:00.012455
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/PLA8343/PLA8343-Planeaciónestratégica-20-1.csv. Tiempo: 0:00:00.001037
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/PLA8343/PLA8343-Planeaciónestratégica-20-1.xlsx. Tiempo: 0:00:00.012640
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/PLA8343/PLA8343-Planeaciónestratégica-20-2.csv. Tiempo: 0:00:00.001018
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/PLA8343/PLA8343-Planeaciónestratégica-20-2.xlsx. Tiempo: 0:00:00.011734
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/PLA8343/PLA8343-Planeaciónestratégica-20-3.csv. Tiempo: 0:00:00.000996
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/PLA8343/PLA8343-Planeaciónestratégica-20-3.xlsx. Tiempo: 0:00:00.011989
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/PLA8343/PLA8343-Planeaciónestratégica-20-4.csv. Tiempo: 0:00:00.001013
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/PLA8343/PLA8343-Planeaciónestratégica-20-4.xlsx. Tiempo: 0:00:00.012160
# Creado archivo CSV: Ruta Trabajo Final/Semestre 9/INV9344/INV9344-Investigacióndemercadosyanálisisdelacompetencia-20-1.csv. Tiempo: 0:00:00.001039
# Creado archivo Excel: Ruta Trabajo Final/Semestre 9/INV9344/INV9344-Investigacióndemercadosyanálisisdelacompetencia-20-1.xlsx. Tiempo: 0:00:00.012127
# Creado archivo CSV: Ruta Trabajo Final/Semestre 9/INV9344/INV9344-Investigacióndemercadosyanálisisdelacompetencia-20-2.csv. Tiempo: 0:00:00.000991
# Creado archivo Excel: Ruta Trabajo Final/Semestre 9/INV9344/INV9344-Investigacióndemercadosyanálisisdelacompetencia-20-2.xlsx. Tiempo: 0:00:00.011596
# Creado archivo CSV: Ruta Trabajo Final/Semestre 9/INV9344/INV9344-Investigacióndemercadosyanálisisdelacompetencia-20-3.csv. Tiempo: 0:00:00.000967
# Creado archivo Excel: Ruta Trabajo Final/Semestre 9/INV9344/INV9344-Investigacióndemercadosyanálisisdelacompetencia-20-3.xlsx. Tiempo: 0:00:00.011999
# Creado archivo CSV: Ruta Trabajo Final/Semestre 9/INV9344/INV9344-Investigacióndemercadosyanálisisdelacompetencia-10-4.csv. Tiempo: 0:00:00.001061
# Creado archivo Excel: Ruta Trabajo Final/Semestre 9/INV9344/INV9344-Investigacióndemercadosyanálisisdelacompetencia-10-4.xlsx. Tiempo: 0:00:00.018927
# Creado archivo CSV: Ruta Trabajo Final/Semestre 9/PRÁ9345/PRÁ9345-Prácticasprofesionales-20-1.csv. Tiempo: 0:00:00.001121
# Creado archivo Excel: Ruta Trabajo Final/Semestre 9/PRÁ9345/PRÁ9345-Prácticasprofesionales-20-1.xlsx. Tiempo: 0:00:00.012316
# Creado archivo CSV: Ruta Trabajo Final/Semestre 9/PRÁ9345/PRÁ9345-Prácticasprofesionales-20-2.csv. Tiempo: 0:00:00.001114
# Creado archivo Excel: Ruta Trabajo Final/Semestre 9/PRÁ9345/PRÁ9345-Prácticasprofesionales-20-2.xlsx. Tiempo: 0:00:00.012418
# Creado archivo CSV: Ruta Trabajo Final/Semestre 9/PRÁ9345/PRÁ9345-Prácticasprofesionales-20-3.csv. Tiempo: 0:00:00.001114
# Creado archivo Excel: Ruta Trabajo Final/Semestre 9/PRÁ9345/PRÁ9345-Prácticasprofesionales-20-3.xlsx. Tiempo: 0:00:00.013708
# Creado archivo CSV: Ruta Trabajo Final/Semestre 9/PRÁ9345/PRÁ9345-Prácticasprofesionales-10-4.csv. Tiempo: 0:00:00.001098
# Creado archivo Excel: Ruta Trabajo Final/Semestre 9/PRÁ9345/PRÁ9345-Prácticasprofesionales-10-4.xlsx. Tiempo: 0:00:00.009788
# Fin de la creación de archivos de cursos. Tiempo total: 0:00:03.534763
# Total de archivos creados: 404
# Total de acciones realizadas: 808

# %%
# Función para buscar un estudiante y sus cursos
def buscar_estudiante(nombre_completo, students, courses):
    estudiante = next((est for est in students if est['Nombre Completo'] == nombre_completo), None)
    if estudiante is None:
        return f"Error: El estudiante {nombre_completo} no existe."

    semestre = estudiante['Semestre']
    cursos_matriculados = [info['Nombre'] for code, info in courses.items() if semestre in info['Semestres']]
    cursos_str = "\n".join(cursos_matriculados)
    return f"Estudiante: {nombre_completo}\nSemestre: {semestre}\nCursos matriculados:\n{cursos_str}"

# Pedir al usuario el nombre del estudiante
nombre_estudiante = input("Ingrese el nombre completo del estudiante: ")
resultado = buscar_estudiante(nombre_estudiante, students, courses)
print(resultado)
# Out:
# Ingrese el nombre completo del estudiante:  Lucas  Moreno
# Estudiante:  Lucas  Moreno
# Semestre: 1
# Cursos matriculados:
# INGLÉS I
# INTRODUCCIÓN A LA INGENIERÍA INDUSTRIAL
# ÁLGEBRA Y TRIGONOMETRÍA
# GEOMETRÍA VECTORIAL Y ANALÍTICA
# CÁLCULO DIFERENCIAL
# LECTOESCRITURA
# VIVAMOS LA UNIVERSIDAD

# %%
import pandas as pd
import random
import os
import datetime
import logging
import platform

# Crear el directorio de logs si no existe
if not os.path.exists('logs'):
    os.makedirs('logs')

# Configuración del logger
log_file_path = os.path.join('logs', 'log.txt')
logging.basicConfig(filename=log_file_path, level=logging.INFO, format='%(asctime)s\t%(message)s')

# Función para registrar eventos con información adicional
def log_event(message):
    logging.info(message)

# Encabezado del log con información del sistema y usuario
system_info = platform.uname()
log_event(f"Sistema: {system_info.system}")
log_event(f"Nodo: {system_info.node}")
log_event(f"Release: {system_info.release}")
log_event(f"Versión: {system_info.version}")
log_event(f"Máquina: {system_info.machine}")
log_event(f"Procesador: {system_info.processor}")
log_event(f"_____________________________________________________________________________________")

# Función para leer nombres y apellidos de los archivos proporcionados
def read_names(file):
    return pd.read_csv(file, header=None, skiprows=1, encoding='utf-8').squeeze().tolist()

# Generación de datos únicos para los estudiantes
def generate_students(num_students, first_names, last_names):
    students = []
    unique_names = set()
    while len(students) < num_students:
        full_name = f"{random.choice(first_names)} {random.choice(last_names)}"
        if full_name not in unique_names:
            unique_names.add(full_name)
            students.append({'Nombre Completo': full_name})
    return students

# Distribución de estudiantes entre los semestres
def distribute_students(students):
    distribution = [0.14, 0.13, 0.12, 0.11, 0.10, 0.10, 0.09, 0.08, 0.07, 0.06]
    semester_counts = [int(len(students) * p) for p in distribution]
    semesters = []
    for i, count in enumerate(semester_counts):
        semesters.extend([i + 1] * count)
    random.shuffle(semesters)
    for student, semester in zip(students, semesters):
        student['Semestre'] = semester
    return students

# Función para obtener las iniciales del curso
def obtener_iniciales(nombre):
    palabras_comunes = {"DE", "LA", "DEL", "Y", "EL", "LOS", "LAS"}
    palabras = nombre.split()
    iniciales = [palabra[:3] for palabra in palabras if palabra.upper() not in palabras_comunes]
    return "".join(iniciales).upper()[:3]

# Función para calcular HTD y HTI basadas en los créditos
def calcular_horas(creditos):
    if creditos == 4:
        return 96, 120
    if creditos == 3:
        return 64, 80
    if creditos == 2:
        return 32, 64
    if creditos == 1:
        return 16, 32
    return 0, 0

# Generar el código único para cada materia
def generar_codigo(nombre, nivel, creditos, consecutivo):
    iniciales = obtener_iniciales(nombre)
    return f"{iniciales}{nivel}{creditos}{consecutivo}"

# Crear archivos de cursos
def create_course_files(students, courses, folder_path):
    start_time = datetime.datetime.now()
    log_event("Inicio de la creación de archivos de cursos")

    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
    grouped = {course: [] for course in courses}

    for student in students:
        for course, info in courses.items():
            if student['Semestre'] in info['Semestres']:
                grouped[course].append(student)

    for course, data in grouped.items():
        course_path = os.path.join(folder_path, f"Semestre {courses[course]['Semestres'][0]}", course)
        if not os.path.exists(course_path):
            os.makedirs(course_path)
        num_groups = len(data) // courses[course]['Cupo'] + (1 if len(data) % courses[course]['Cupo'] else 0)
        for i in range(num_groups):
            group_data = data[i * courses[course]['Cupo']:(i + 1) * courses[course]['Cupo']]
            if group_data:
                df = pd.DataFrame(group_data)[['Nombre Completo']]
                code = course
                course_name = courses[course]['Nombre'].replace(" ", "").capitalize()
                student_count = len(group_data)
                group_code = i + 1
                filename = f"{code}-{course_name}-{student_count}-{group_code}"
                filepath_csv = os.path.join(course_path, f"{filename}.csv")
                filepath_excel = os.path.join(course_path, f"{filename}.xlsx")
              # Crear archivo CSV
                csv_start_time = datetime.datetime.now()
                df.to_csv(filepath_csv, index=False, encoding='utf-8-sig')
                csv_end_time = datetime.datetime.now()
                csv_time_taken = csv_end_time - csv_start_time
                log_event(f'Creado archivo CSV: {filepath_csv}. Tiempo: {csv_time_taken}')

                # Crear archivo Excel
                excel_start_time = datetime.datetime.now()
                df.to_excel(filepath_excel, index=False)
                excel_end_time = datetime.datetime.now()
                excel_time_taken = excel_end_time - excel_start_time
                log_event(f'Creado archivo Excel: {filepath_excel}. Tiempo: {excel_time_taken}')

    end_time = datetime.datetime.now()
    total_time_taken = end_time - start_time
    log_event(f"Fin de la creación de archivos de cursos. Tiempo total: {total_time_taken}")


# Lista de materias con información
materias = [
    {"nivel": 1, "nombre": "INGLÉS I", "creditos": 1},
    {"nivel": 1, "nombre": "INTRODUCCIÓN A LA INGENIERÍA INDUSTRIAL", "creditos": 1},
    {"nivel": 1, "nombre": "ÁLGEBRA Y TRIGONOMETRÍA", "creditos": 3},
    {"nivel": 1, "nombre": "GEOMETRÍA VECTORIAL Y ANALÍTICA", "creditos": 3},
    {"nivel": 1, "nombre": "CÁLCULO DIFERENCIAL", "creditos": 3},
    {"nivel": 1, "nombre": "LECTOESCRITURA", "creditos": 3},
    {"nivel": 1, "nombre": "VIVAMOS LA UNIVERSIDAD", "creditos": 1},
    {"nivel": 2, "nombre": "INGLÉS II", "creditos": 1},
    {"nivel": 2, "nombre": "GESTIÓN DE LAS ORGANIZACIONES", "creditos": 3},
    {"nivel": 2, "nombre": "HABILIDADES GERENCIALES", "creditos": 3},
    {"nivel": 2, "nombre": "ÁLGEBRA LINEAL", "creditos": 3},
    {"nivel": 2, "nombre": "CÁLCULO INTEGRAL", "creditos": 3},
    {"nivel": 2, "nombre": "DESCUBRIENDO LA FÍSICA", "creditos": 3},
    {"nivel": 3, "nombre": "INGLÉS III", "creditos": 1},
    {"nivel": 3, "nombre": "GESTIÓN CONTABLE", "creditos": 3},
    {"nivel": 3, "nombre": "TEORÍA GENERAL DE SISTEMAS", "creditos": 3},
    {"nivel": 3, "nombre": "PROBABILIDAD E INFERENCIA ESTADÍSTICA", "creditos": 3},
    {"nivel": 3, "nombre": "ALGORITMIA Y PROGRAMACIÓN", "creditos": 3},
    {"nivel": 3, "nombre": "FÍSICA MECÁNICA", "creditos": 3},
    {"nivel": 4, "nombre": "INGLÉS IV", "creditos": 1},
    {"nivel": 4, "nombre": "GESTIÓN DE MÉTODOS Y TIEMPOS", "creditos": 4},
    {"nivel": 4, "nombre": "INGENIERÍA ECONÓMICA", "creditos": 3},
    {"nivel": 4, "nombre": "DISEÑO DE EXPERIMENTOS Y ANÁLISIS DE REGRESIÓN", "creditos": 3},
    {"nivel": 4, "nombre": "OPTIMIZACIÓN", "creditos": 3},
    {"nivel": 5, "nombre": "INGLÉS V", "creditos": 1},
    {"nivel": 5, "nombre": "DINÁMICA DE SISTEMAS", "creditos": 3},
    {"nivel": 5, "nombre": "GESTIÓN POR PROCESOS", "creditos": 3},
    {"nivel": 5, "nombre": "GESTIÓN FINANCIERA", "creditos": 3},
    {"nivel": 5, "nombre": "MUESTREO Y SERIES DE TIEMPO", "creditos": 3},
    {"nivel": 5, "nombre": "PROCESOS ESTOCÁSTICOS Y ANÁLISIS DE DECISIÓN", "creditos": 3},
    {"nivel": 6, "nombre": "INGLÉS VI", "creditos": 1},
    {"nivel": 6, "nombre": "GESTIÓN TECNOLÓGICA", "creditos": 3},
    {"nivel": 6, "nombre": "NORMALIZACIÓN Y CONTROL DE CALIDAD", "creditos": 3},
    {"nivel": 6, "nombre": "SIMULACIÓN", "creditos": 3},
    {"nivel": 6, "nombre": "SEGURIDAD Y SALUD EN EL TRABAJO", "creditos": 3},
    {"nivel": 7, "nombre": "GESTIÓN AMBIENTAL", "creditos": 3},
    {"nivel": 7, "nombre": "FORMULACIÓN Y EVALUACIÓN DE PROYECTOS", "creditos": 3},
    {"nivel": 7, "nombre": "GESTIÓN LOGÍSTICA Y DE LA CADENA DE SUMINISTRO", "creditos": 3},
    {"nivel": 7, "nombre": "MODELACIÓN DE SISTEMAS Y SIMULACIÓN DE PROCESOS", "creditos": 3},
    {"nivel": 8, "nombre": "GESTIÓN DEL TALENTO HUMANO", "creditos": 3},
    {"nivel": 8, "nombre": "GESTIÓN DE SERVICIOS", "creditos": 3},
    {"nivel": 8, "nombre": "PLANIFICACIÓN Y CONTROL DE LA PRODUCCIÓN", "creditos": 3},
    {"nivel": 8, "nombre": "PLANEACIÓN ESTRATÉGICA", "creditos": 3},
    {"nivel": 9, "nombre": "INVESTIGACIÓN DE MERCADOS Y ANÁLISIS DE LA COMPETENCIA", "creditos": 3},
    {"nivel": 9, "nombre": "PRÁCTICAS PROFESIONALES", "creditos": 3},
]

# Cursos y su configuración
courses = {}
consecutivo = 1
for materia in materias:
    codigo = generar_codigo(materia['nombre'], materia['nivel'], materia['creditos'], consecutivo)
    courses[codigo] = {
        'Semestres': [materia['nivel']],
        'Cupo': 30 if materia['nivel'] < 4 else 25 if materia['nivel'] < 7 else 20,
        'HTD': calcular_horas(materia['creditos'])[0],
        'HTI': calcular_horas(materia['creditos'])[1],
        'Nombre': materia['nombre']
    }
    consecutivo += 1

# Archivos de nombres y apellidos
first_names = read_names('nombres.csv')
last_names = read_names('apellidos.csv')

# Generar y distribuir estudiantes
students = generate_students(1000, first_names, last_names)
students = distribute_students(students)

# Crear archivos de cursos
create_course_files(students, courses, 'Ruta Trabajo Final')

# Finalizar el log de eventos con un resumen
total_files = sum([len(files) for r, d, files in os.walk('Ruta Trabajo Final')])
log_event(f"Total de archivos creados: {total_files}")
log_event(f"Total de acciones realizadas: {total_files * 2}")  # Cada archivo implica crear CSV y Excel, así que se multiplica por 2
